# %%
"""
开源数据分析与操作的工具
核心：
    DataFrame（类似表格）
    Series（类似表格中的一列）
"""
# Out:
# '\n开源数据分析与操作的工具\n核心：\n    DataFrame（类似表格）\n    Series（类似表格中的一列）\n'

# %%
"""
Series
常见属性
        index
        values
        dtype
        size
        shape
"""

# %%
import pandas as pd

# 创建DataFrame
df = pd.DataFrame([
        {'姓名': '张三', '年龄': 28, '城市': '北京', '工资': 8500, '部门': '技术部'},
        {'姓名': '李四', '年龄': 34, '城市': '上海', '工资': 12000, '部门': '市场部'},
        {'姓名': '王五', '年龄': 26, '城市': '深圳', '工资': 9500, '部门': '技术部'},
        {'姓名': '赵六', '年龄': 31, '城市': '广州', '工资': 7800, '部门': '财务部'},
        {'姓名': '孙七', '年龄': 29, '城市': '杭州', '工资': 11000, '部门': '市场部'},
        {'姓名': '周八', '年龄': 35, '城市': '成都', '工资': 9200, '部门': '技术部'},
        {'姓名': '吴九', '年龄': 27, '城市': '武汉', '工资': 8800, '部门': '财务部'},
        {'姓名': '郑十', '年龄': 32, '城市': '南京', '工资': 10500, '部门': '人事部'}
])
df
# Out:
#    姓名  年龄  城市     工资   部门
# 0  张三  28  北京   8500  技术部
# 1  李四  34  上海  12000  市场部
# 2  王五  26  深圳   9500  技术部
# 3  赵六  31  广州   7800  财务部
# 4  孙七  29  杭州  11000  市场部
# 5  周八  35  成都   9200  技术部
# 6  吴九  27  武汉   8800  财务部
# 7  郑十  32  南京  10500  人事部

# %%
# 统计计算
df['工资']
# Out:
# 0     8500
# 1    12000
# 2     9500
# 3     7800
# 4    11000
# 5     9200
# 6     8800
# 7    10500
# Name: 工资, dtype: int64

# %%
# 注意只会输出最后一个输出，除非用 print 强制输出
f"最大{df['工资'].max()}，最小{df['工资'].min()}，平均{df['工资'].mean():.2f}"
# Out:
# '最大12000，最小7800，平均9662.50'

# %%
df.columns
# Out:
# Index(['姓名', '年龄', '城市', '工资', '部门'], dtype='str')

# %%
df.index.tolist()
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
df.columns.tolist()
# Out:
# ['姓名', '年龄', '城市', '工资', '部门']

# %%
df.values.tolist()
# Out:
# [['张三', 28, '北京', 8500, '技术部'],
#  ['李四', 34, '上海', 12000, '市场部'],
#  ['王五', 26, '深圳', 9500, '技术部'],
#  ['赵六', 31, '广州', 7800, '财务部'],
#  ['孙七', 29, '杭州', 11000, '市场部'],
#  ['周八', 35, '成都', 9200, '技术部'],
#  ['吴九', 27, '武汉', 8800, '财务部'],
#  ['郑十', 32, '南京', 10500, '人事部']]

# %%
df.size
# Out:
# 40

# %%
df.dtypes
# Out:
# 姓名      str
# 年龄    int64
# 城市      str
# 工资    int64
# 部门      str
# dtype: object

# %%
df.shape
# Out:
# (8, 5)

# %%
"""
Series
只有一列，所以只有一维
DataFrame 提取出的一列
常见属性
        index
        values
        dtype
        size
        shape
"""

# %%
ser1 = pd.Series([10,20,30,40])
ser2 = pd.Series((10,20,30,40), index = ['a','b','c','d'])
ser3 = pd.Series({'a' : 10, 'b' : 20, 'c' : 30, 'd' : 40})

# %%
ser4 = df['工资']

# %%
ser4.index.tolist()
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
ser4.values.tolist()
# Out:
# [8500, 12000, 9500, 7800, 11000, 9200, 8800, 10500]

# %%
ser4
# Out:
# 0     8500
# 1    12000
# 2     9500
# 3     7800
# 4    11000
# 5     9200
# 6     8800
# 7    10500
# Name: 工资, dtype: int64
