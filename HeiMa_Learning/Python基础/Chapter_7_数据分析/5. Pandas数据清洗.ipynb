# %%
"""
处理重复、缺失、异常值，统一数据格式，保证数据一致性
"""
# Out:
# '\n处理重复、缺失、异常值，统一数据格式，保证数据一致性\n'

# %%
import pandas as pd

# %%
# 设置显示行数，共展示 x 行
pd.set_option('display.min_rows', 30)

# 导入数据
df1 = pd.read_csv('./Project_Data/5. Pandas_sales_data.csv', encoding='UTF-8')
df1
# Out:
#         订单号  产品类别   产品名称  销售数量    单价  订单金额 销售区域        订单日期
# 0   ORD-001  电子产品   智能手机     2  3999  7998   华东  2026-01-05
# 1   ORD-002  服装鞋帽     T恤     5    89   445   华南  2026-01-06
# 2   ORD-003  食品饮料    纯牛奶    10    68   680   华北  2026-01-07
# 3   ORD-004  家居用品     台灯     3   159   477   华东  2026-01-08
# 4   ORD-005  办公耗材  A4打印纸     8    22   176   华南  2026-01-09
# 5   ORD-006  电子产品   蓝牙耳机     4   299  1196   华北  2026-01-10
# 6   ORD-007  服装鞋帽    运动鞋     2   459   918   华东  2026-01-11
# 7   ORD-008  食品饮料    矿泉水    20    36   720   华南  2026-01-12
# 8   ORD-009  家居用品    收纳箱     6    79   474   华北  2026-01-13
# 9   ORD-010  办公耗材    中性笔    30     3    90   华东  2026-01-14
# 10  ORD-011  电子产品   平板电脑     1  2899  2899   华南  2026-01-15
# 11  ORD-012  服装鞋帽    羽绒服     2   899  1798   华北  2026-01-16
# 12  ORD-013  食品饮料     薯片    15    12   180   华东  2026-01-17
# 13  ORD-014  家居用品    保温杯     4   129   516   华南  2026-01-18
# 14  ORD-015  办公耗材    文件夹    12     8    96   华北  2026-01-19
# ...

# %%
df1.isnull()
# Out:
#       订单号   产品类别   产品名称   销售数量     单价   订单金额   销售区域   订单日期
# 0   False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False  False
# 12  False  False  False  False  False  False  False  False
# 13  False  False  False  False  False  False  False  False
# 14  False  False  False  False  False  False  False  False
# ...
